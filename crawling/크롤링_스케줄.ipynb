# %%
from selenium import webdriver as wd
import csv
import time
driver = wd.Chrome(executable_path="chromedriver.exe")
url = 'https://www.airportal.go.kr/life/airinfo/RaSkeFrmMain.jsp'
driver.get(url)

#출발 공항 선택
driver.switch_to.frame('main')
driver.switch_to.frame('airportframe')
driver.find_element_by_xpath('//*[@name="ser_airport"]/option[text()="제주"]').click()

#도착 공항 선택
driver.switch_to.parent_frame()
driver.switch_to.frame(1)
driver.find_element_by_xpath('//*[@name="ser_region"]/option[text()="동북아시아"]').click()
driver.find_element_by_xpath('//*[@name="ser_nation"]/option[text()="한국"]').click()
driver.find_element_by_xpath('//*[@name="ser_airport"]/option[text()="광주"]').click()

#기간 선택(from)
driver.switch_to.parent_frame()
driver.find_element_by_name('current_dt_from').clear()
driver.find_element_by_name('current_dt_from').send_keys('20170201')

#기간 선택(to)
driver.find_element_by_name('current_dt_to').clear()
driver.find_element_by_name('current_dt_to').send_keys('20170228')

#용도 선택
driver.find_element_by_xpath('//*[@name="regCls"]/option[text()="여객"]').click()

#항공사 선택
driver.find_element_by_xpath('//*[@name="al_icao"]/option[text()="대한항공"]').click()

#결과 크롤링
driver.switch_to.parent_frame()
driver.switch_to.frame('main')
driver.switch_to.frame('sframe')
tbody = driver.find_element_by_xpath('/html/body/form/table/tbody/tr[3]/td/table/tbody')
tr = tbody.find_elements_by_tag_name('tr')
num = int(driver.find_element_by_xpath('/html/body/form/table/tbody/tr[4]/td/table/tbody/tr[4]/td/table/tbody/tr/td[3]/font[1]').text)
pages = num // 10 + 1
print(pages%10)
print("----------------------------%d 건, %d 페이지----------------------------"%(num, pages))
col_name = ["일자", "공백1", "공백2", "항공사", "편명", "도착", "계획", "예상", "출발", "구분", "현황"]  
with open('2017_test.csv', 'w', -1, newline='') as f :
    w = csv.writer(f)
    w.writerow(col_name)
    for p in range(pages // 10 ): 
        for n in range(11):
            # 1쪽 1페이지
            if (p == 0) & (n == 0) : 
                tbody = driver.find_element_by_xpath('/html/body/form/table/tbody/tr[3]/td/table/tbody')
                tr = tbody.find_elements_by_tag_name('tr')
                for td in tr:
                    row = td.text
                    row_list = row.split(' ')
                    print(row_list)
                    w.writerow(row_list)
                    time.sleep(0.1)
                print('--------------------------%d 장 , %d 페이지 ---------------------'%(p+1, n+1))
            else :   
                #1쪽이 아닌 경우, next 버튼 누르기
                if (p != 0) &(n == 10) :
                    driver.find_element_by_xpath('/html/body/form/table/tbody/tr[4]/td/table/tbody/tr[4]/td/table/tbody/tr/td[2]/font/font/a[10]/font/img').click()
                    tbody = driver.find_element_by_xpath('/html/body/form/table/tbody/tr[3]/td/table/tbody')
                    tr = tbody.find_elements_by_tag_name('tr')
                    for td in tr:
                        row = td.text
                        row_list = row.split(' ')
                        print(row_list)
                        w.writerow(row_list)
                        time.sleep(0.1)
                    print('--------------------------%d 장 , %d 페이지 ---------------------'%(p+1, n+1))
                else : 
                    # 첫번째 페이지
                    if n == 0 : 
                        tbody = driver.find_element_by_xpath('/html/body/form/table/tbody/tr[3]/td/table/tbody')
                        tr = tbody.find_elements_by_tag_name('tr')
                        for td in tr:
                            row = td.text
                            row_list = row.split(' ')
                            print(row_list)
                            w.writerow(row_list)
                            time.sleep(0.1)
                        print('--------------------------%d 장 , %d 페이지 ---------------------'%(p+1, n+1))
                    else : 
                        #1쪽인 경우 
                        if p == 0 : 
                            xpath1 = '/html/body/form/table/tbody/tr[4]/td/table/tbody/tr[4]/td/table/tbody/tr/td[2]/font/a['
                            xpath2 = ']/font'
                            xpath = xpath1 + str(n) + xpath2
                            driver.find_element_by_xpath(xpath).click()

                            tbody = driver.find_element_by_xpath('/html/body/form/table/tbody/tr[3]/td/table/tbody')
                            tr = tbody.find_elements_by_tag_name('tr')
                            for td in tr:
                                row = td.text
                                row_list = row.split(' ')
                                print(row_list)
                                w.writerow(row_list)
                                time.sleep(0.1)
                            print('--------------------------%d 장 , %d 페이지 ---------------------'%(p+1, n+1))
                        else : 
                            xpath1 = '/html/body/form/table/tbody/tr[4]/td/table/tbody/tr[4]/td/table/tbody/tr/td[2]/font/font/a['
                            xpath2 = ']/font'
                            xpath = xpath1 + str(n) + xpath2
                            driver.find_element_by_xpath(xpath).click()

                            tbody = driver.find_element_by_xpath('/html/body/form/table/tbody/tr[3]/td/table/tbody')
                            tr = tbody.find_elements_by_tag_name('tr')
                            for td in tr:
                                row = td.text
                                row_list = row.split(' ')
                                print(row_list)
                                w.writerow(row_list)
                                time.sleep(0.1)
                            print('--------------------------%d 장 , %d 페이지 ---------------------'%(p+1, n+1))

    
    if(pages%10 != 0):
        for a in range(pages%10):
            for n in range(11):
                # 1쪽 1페이지
                if (a == 0) & (n == 0) : 
                    tbody = driver.find_element_by_xpath('/html/body/form/table/tbody/tr[3]/td/table/tbody')
                    tr = tbody.find_elements_by_tag_name('tr')
                    for td in tr:
                        row = td.text
                        row_list = row.split(' ')
                        print(row_list)
                        w.writerow(row_list)
                        time.sleep(0.1)
                    print('--------------------------%d 페이지 ---------------------'%(n+1))
                else :   
                    if n == 0 : 
                            tbody = driver.find_element_by_xpath('/html/body/form/table/tbody/tr[3]/td/table/tbody')
                            tr = tbody.find_elements_by_tag_name('tr')
                            for td in tr:
                                row = td.text
                                row_list = row.split(' ')
                                print(row_list)
                                w.writerow(row_list)
                                time.sleep(0.1)
                            print('--------------------------%d 페이지 ---------------------'%(n+1))
                    else :  
                        if a == 0 : 
                            xpath1 = '/html/body/form/table/tbody/tr[4]/td/table/tbody/tr[4]/td/table/tbody/tr/td[2]/font/font/a['
                            xpath2 = ']/font'
                            xpath = xpath1 + str(n) + xpath2
                            driver.find_element_by_xpath(xpath).click()

                            tbody = driver.find_element_by_xpath('/html/body/form/table/tbody/tr[3]/td/table/tbody')
                            tr = tbody.find_elements_by_tag_name('tr')
                            for td in tr:
                                row = td.text
                                row_list = row.split(' ')
                                print(row_list)
                                w.writerow(row_list)
                                time.sleep(0.1)
                            print('--------------------------%d 페이지 ---------------------'%(n+1))
# Out:
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = wd.Chrome(executable_path="chromedriver.exe")
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:11: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('//*[@name="ser_airport"]/option[text()="제주"]').click()
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:16: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('//*[@name="ser_region"]/option[text()="동북아시아"]').click()
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:17: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('//*[@name="ser_nation"]/option[text()="한국"]').click()
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:18: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('//*[@name="ser_airport"]/option[text()="광주"]').click()
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:22: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   driver.find_element_by_name('current_dt_from').clear()
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:23: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   driver.find_element_by_name('current_dt_from').send_keys('20170201')
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:26: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   driver.find_element_by_name('current_dt_to').clear()
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:27: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   driver.find_element_by_name('current_dt_to').send_keys('20170228')
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:30: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('//*[@name="regCls"]/option[text()="여객"]').click()
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:33: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('//*[@name="al_icao"]/option[text()="대한항공"]').click()
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:39: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   tbody = driver.find_element_by_xpath('/html/body/form/table/tbody/tr[3]/td/table/tbody')
# C:\Users\kygam\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:359: UserWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   warnings.warn("find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead")
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:41: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   num = int(driver.find_element_by_xpath('/html/body/form/table/tbody/tr[4]/td/table/tbody/tr[4]/td/table/tbody/tr/td[3]/font[1]').text)
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:53: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   tbody = driver.find_element_by_xpath('/html/body/form/table/tbody/tr[3]/td/table/tbody')
# 5
# ----------------------------140 건, 15 페이지----------------------------
# ['2017-02-28', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:47', '여객', '출발']
# ['']
# ['2017-02-28', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:09', '여객', '출발']
# ['']
# ['2017-02-28', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:10', '여객', '출발']
# ['']
# ['2017-02-28', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '17:04', '17:01', '여객', '지연']
# ['']
# ['2017-02-28', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:15', '여객', '출발']
# ['']
# ['2017-02-27', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:50', '여객', '출발']
# ['']
# ['2017-02-27', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:05', '여객', '출발']
# ['']
# ['2017-02-27', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:38', '15:32', '여객', '지연']
# ['']
# ['2017-02-27', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:21', '여객', '출발']
# ['']
# ['2017-02-27', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:34', '여객', '출발']
# ['']
# --------------------------1 장 , 1 페이지 ---------------------
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:93: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath(xpath).click()
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:95: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   tbody = driver.find_element_by_xpath('/html/body/form/table/tbody/tr[3]/td/table/tbody')
# ['2017-02-26', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:56', '여객', '출발']
# ['']
# ['2017-02-26', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:07', '여객', '출발']
# ['']
# ['2017-02-26', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:36', '15:35', '여객', '지연']
# ['']
# ['2017-02-26', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:14', '여객', '출발']
# ['']
# ['2017-02-26', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:25', '여객', '출발']
# ['']
# ['2017-02-25', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:50', '여객', '출발']
# ['']
# ['2017-02-25', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '11:56', '여객', '출발']
# ['']
# ['2017-02-25', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:15', '여객', '출발']
# ['']
# ['2017-02-25', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:16', '여객', '출발']
# ['']
# ['2017-02-25', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:20', '여객', '출발']
# ['']
# --------------------------1 장 , 2 페이지 ---------------------
# ['2017-02-24', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:46', '여객', '출발']
# ['']
# ['2017-02-24', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:06', '여객', '출발']
# ['']
# ['2017-02-24', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:05', '15:05', '15:20', '여객', '출발']
# ['']
# ['2017-02-24', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:22', '여객', '출발']
# ['']
# ['2017-02-24', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:50', '18:45', '여객', '지연']
# ['']
# ['2017-02-23', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:54', '여객', '출발']
# ['']
# ['2017-02-23', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:04', '여객', '출발']
# ['']
# ['2017-02-23', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:24', '여객', '출발']
# ['']
# ['2017-02-23', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:36', '16:32', '여객', '지연']
# ['']
# ['2017-02-23', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:20', '여객', '출발']
# ['']
# --------------------------1 장 , 3 페이지 ---------------------
# ['2017-02-22', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '09:04', '여객', '출발']
# ['']
# ['2017-02-22', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:06', '여객', '출발']
# ['']
# ['2017-02-22', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:55', '15:39', '여객', '지연']
# ['']
# ['2017-02-22', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '17:42', '17:38', '여객', '지연']
# ['']
# ['2017-02-22', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:43', '18:36', '여객', '지연']
# ['']
# ['2017-02-21', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:49', '여객', '출발']
# ['']
# ['2017-02-21', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '11:55', '여객', '출발']
# ['']
# ['2017-02-21', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:34', '여객', '지연']
# ['']
# ['2017-02-21', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '17:14', '17:14', '여객', '지연']
# ['']
# ['2017-02-21', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:23', '여객', '출발']
# ['']
# --------------------------1 장 , 4 페이지 ---------------------
# ['2017-02-20', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '09:45', '09:41', '여객', '지연']
# ['']
# ['2017-02-20', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:06', '여객', '출발']
# ['']
# ['2017-02-20', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:42', '15:32', '여객', '지연']
# ['']
# ['2017-02-20', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '17:12', '17:12', '여객', '지연']
# ['']
# ['2017-02-20', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:26', '여객', '출발']
# ['']
# ['2017-02-19', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:56', '여객', '출발']
# ['']
# ['2017-02-19', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '11:59', '여객', '출발']
# ['']
# ['2017-02-19', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:39', '15:36', '여객', '지연']
# ['']
# ['2017-02-19', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '15:18', '16:24', '여객', '출발']
# ['']
# ['2017-02-19', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '19:38', '19:23', '여객', '지연']
# ['']
# --------------------------1 장 , 5 페이지 ---------------------
# ['2017-02-18', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:56', '여객', '출발']
# ['']
# ['2017-02-18', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '11:56', '여객', '출발']
# ['']
# ['2017-02-18', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:10', '여객', '출발']
# ['']
# ['2017-02-18', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:12', '여객', '출발']
# ['']
# ['2017-02-18', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:17', '여객', '출발']
# ['']
# ['2017-02-17', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:50', '여객', '출발']
# ['']
# ['2017-02-17', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:07', '여객', '출발']
# ['']
# ['2017-02-17', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:05', '15:05', '15:11', '여객', '출발']
# ['']
# ['2017-02-17', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:13', '여객', '출발']
# ['']
# ['2017-02-17', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:40', '여객', '지연']
# ['']
# --------------------------1 장 , 6 페이지 ---------------------
# ['2017-02-16', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '09:00', '여객', '출발']
# ['']
# ['2017-02-16', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:09', '여객', '출발']
# ['']
# ['2017-02-16', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:28', '여객', '출발']
# ['']
# ['2017-02-16', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:21', '여객', '출발']
# ['']
# ['2017-02-16', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:31', '여객', '출발']
# ['']
# ['2017-02-15', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:49', '여객', '출발']
# ['']
# ['2017-02-15', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:02', '여객', '출발']
# ['']
# ['2017-02-15', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:15', '여객', '출발']
# ['']
# ['2017-02-15', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '17:07', '17:01', '여객', '지연']
# ['']
# ['2017-02-15', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:24', '여객', '출발']
# ['']
# --------------------------1 장 , 7 페이지 ---------------------
# ['2017-02-14', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:45', '여객', '출발']
# ['']
# ['2017-02-14', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:00', '여객', '출발']
# ['']
# ['2017-02-14', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:18', '여객', '출발']
# ['']
# ['2017-02-14', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '17:00', '16:48', '여객', '지연']
# ['']
# ['2017-02-14', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:19', '여객', '출발']
# ['']
# ['2017-02-13', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '09:22', '09:16', '여객', '지연']
# ['']
# ['2017-02-13', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:01', '여객', '출발']
# ['']
# ['2017-02-13', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:10', '여객', '출발']
# ['']
# ['2017-02-13', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:35', '16:31', '여객', '지연']
# ['']
# ['2017-02-13', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:33', '여객', '출발']
# ['']
# --------------------------1 장 , 8 페이지 ---------------------
# ['2017-02-12', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:49', '여객', '출발']
# ['']
# ['2017-02-12', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '11:53', '여객', '출발']
# ['']
# ['2017-02-12', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:20', '여객', '출발']
# ['']
# ['2017-02-12', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:14', '여객', '출발']
# ['']
# ['2017-02-12', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:21', '여객', '출발']
# ['']
# ['2017-02-11', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '09:14', '09:07', '여객', '지연']
# ['']
# ['2017-02-11', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '11:56', '여객', '출발']
# ['']
# ['2017-02-11', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:11', '여객', '출발']
# ['']
# ['2017-02-11', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:12', '여객', '출발']
# ['']
# ['2017-02-11', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:23', '여객', '출발']
# ['']
# --------------------------1 장 , 9 페이지 ---------------------
# ['2017-02-10', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '09:18', '09:08', '여객', '지연']
# ['']
# ['2017-02-10', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '13:28', '13:21', '여객', '지연']
# ['']
# ['2017-02-10', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:05', '15:57', '15:53', '여객', '지연']
# ['']
# ['2017-02-10', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:48', '16:39', '여객', '지연']
# ['']
# ['2017-02-10', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:45', '18:39', '여객', '지연']
# ['']
# ['2017-02-09', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:45', '여객', '출발']
# ['']
# ['2017-02-09', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:01', '여객', '출발']
# ['']
# ['2017-02-09', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:10', '여객', '출발']
# ['']
# ['2017-02-09', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:29', '여객', '출발']
# ['']
# ['2017-02-09', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:16', '여객', '출발']
# ['']
# --------------------------1 장 , 10 페이지 ---------------------
# ['2017-02-08', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:46', '여객', '출발']
# ['']
# ['2017-02-08', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:03', '여객', '출발']
# ['']
# ['2017-02-08', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:10', '여객', '출발']
# ['']
# ['2017-02-08', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:27', '여객', '출발']
# ['']
# ['2017-02-08', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:18', '여객', '출발']
# ['']
# ['2017-02-07', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:49', '여객', '출발']
# ['']
# ['2017-02-07', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '11:58', '여객', '출발']
# ['']
# ['2017-02-07', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:14', '여객', '출발']
# ['']
# ['2017-02-07', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:41', '16:39', '여객', '지연']
# ['']
# ['2017-02-07', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:24', '여객', '출발']
# ['']
# --------------------------1 장 , 11 페이지 ---------------------
# ['2017-02-08', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:46', '여객', '출발']
# ['']
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:126: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   tbody = driver.find_element_by_xpath('/html/body/form/table/tbody/tr[3]/td/table/tbody')
# ['2017-02-08', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:03', '여객', '출발']
# ['']
# ['2017-02-08', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:10', '여객', '출발']
# ['']
# ['2017-02-08', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:27', '여객', '출발']
# ['']
# ['2017-02-08', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:18', '여객', '출발']
# ['']
# ['2017-02-07', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:49', '여객', '출발']
# ['']
# ['2017-02-07', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '11:58', '여객', '출발']
# ['']
# ['2017-02-07', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:14', '여객', '출발']
# ['']
# ['2017-02-07', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:41', '16:39', '여객', '지연']
# ['']
# ['2017-02-07', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:24', '여객', '출발']
# ['']
# --------------------------1 페이지 ---------------------
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:151: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath(xpath).click()
# C:\Users\kygam\AppData\Local\Temp/ipykernel_11316/4197701144.py:153: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   tbody = driver.find_element_by_xpath('/html/body/form/table/tbody/tr[3]/td/table/tbody')
# ['2017-02-06', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:44', '여객', '출발']
# ['']
# ['2017-02-06', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:00', '여객', '출발']
# ['']
# ['2017-02-06', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:16', '여객', '출발']
# ['']
# ['2017-02-06', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:18', '여객', '출발']
# ['']
# ['2017-02-06', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:23', '여객', '출발']
# ['']
# ['2017-02-05', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:46', '여객', '출발']
# ['']
# ['2017-02-05', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:02', '여객', '출발']
# ['']
# ['2017-02-05', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:26', '여객', '출발']
# ['']
# ['2017-02-05', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:16', '여객', '출발']
# ['']
# ['2017-02-05', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:16', '여객', '출발']
# ['']
# --------------------------2 페이지 ---------------------
# ['2017-02-04', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:56', '여객', '출발']
# ['']
# ['2017-02-04', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '11:59', '여객', '출발']
# ['']
# ['2017-02-04', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:14', '여객', '출발']
# ['']
# ['2017-02-04', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:25', '여객', '출발']
# ['']
# ['2017-02-04', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:18', '여객', '출발']
# ['']
# ['2017-02-03', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:46', '여객', '출발']
# ['']
# ['2017-02-03', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '11:59', '여객', '출발']
# ['']
# ['2017-02-03', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:05', '15:05', '15:23', '여객', '출발']
# ['']
# ['2017-02-03', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:26', '여객', '출발']
# ['']
# ['2017-02-03', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:28', '여객', '출발']
# ['']
# --------------------------3 페이지 ---------------------
# ['2017-02-02', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:48', '여객', '출발']
# ['']
# ['2017-02-02', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '11:59', '여객', '출발']
# ['']
# ['2017-02-02', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:19', '여객', '출발']
# ['']
# ['2017-02-02', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:16', '여객', '출발']
# ['']
# ['2017-02-02', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:15', '여객', '출발']
# ['']
# ['2017-02-01', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:52', '여객', '출발']
# ['']
# ['2017-02-01', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:01', '여객', '출발']
# ['']
# ['2017-02-01', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:19', '여객', '출발']
# ['']
# ['2017-02-01', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:15', '여객', '출발']
# ['']
# ['2017-02-01', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:17', '여객', '출발']
# ['']
# --------------------------4 페이지 ---------------------
# ['2017-02-02', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:48', '여객', '출발']
# ['']
# ['2017-02-02', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '11:59', '여객', '출발']
# ['']
# ['2017-02-02', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:19', '여객', '출발']
# ['']
# ['2017-02-02', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:16', '여객', '출발']
# ['']
# ['2017-02-02', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:15', '여객', '출발']
# ['']
# ['2017-02-01', '', '', '대한항공', 'KE1902', '제주(CJU)->광주(KWJ)', '08:35', '08:35', '08:52', '여객', '출발']
# ['']
# ['2017-02-01', '', '', '대한항공', 'KE1904', '제주(CJU)->광주(KWJ)', '11:45', '11:45', '12:01', '여객', '출발']
# ['']
# ['2017-02-01', '', '', '대한항공', 'KE1906', '제주(CJU)->광주(KWJ)', '15:00', '15:00', '15:19', '여객', '출발']
# ['']
# ['2017-02-01', '', '', '대한항공', 'KE1900', '제주(CJU)->광주(KWJ)', '16:00', '16:00', '16:15', '여객', '출발']
# ['']
# ['2017-02-01', '', '', '대한항공', 'KE1908', '제주(CJU)->광주(KWJ)', '18:05', '18:05', '18:17', '여객', '출발']
# ['']
# --------------------------5 페이지 ---------------------
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11316/4197701144.py in <module>
#     149                             xpath2 = ']/font'
#     150                             xpath = xpath1 + str(n) + xpath2
# --> 151                             driver.find_element_by_xpath(xpath).click()
#     152
#     153                             tbody = driver.find_element_by_xpath('/html/body/form/table/tbody/tr[3]/td/table/tbody')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     519             stacklevel=2,
#     520         )
# --> 521         return self.find_element(by=By.XPATH, value=xpath)
#     522
#     523     def find_elements_by_xpath(self, xpath) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1246             value = '[name="%s"]' % value
#    1247
# -> 1248         return self.execute(Command.FIND_ELEMENT, {
#    1249             'using': by,
#    1250             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/form/table/tbody/tr[4]/td/table/tbody/tr[4]/td/table/tbody/tr/td[2]/font/font/a[5]/font"}
#   (Session info: chrome=100.0.4896.88)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008B9943+2595139]
# 	Ordinal0 [0x0084C9F1+2148849]
# 	Ordinal0 [0x00744528+1066280]
# 	Ordinal0 [0x00770FD4+1249236]
# 	Ordinal0 [0x007711CB+1249739]
# 	Ordinal0 [0x0079D812+1431570]
# 	Ordinal0 [0x0078BA34+1358388]
# 	Ordinal0 [0x0079BAF2+1424114]
# 	Ordinal0 [0x0078B806+1357830]
# 	Ordinal0 [0x00766086+1204358]
# 	Ordinal0 [0x00766F96+1208214]
# 	GetHandleVerifier [0x00A5B232+1658114]
# 	GetHandleVerifier [0x00B1312C+2411516]
# 	GetHandleVerifier [0x0094F261+560433]
# 	GetHandleVerifier [0x0094E366+556598]
# 	Ordinal0 [0x0085286B+2173035]
# 	Ordinal0 [0x008575F8+2192888]
# 	Ordinal0 [0x008576E5+2193125]
# 	Ordinal0 [0x008611FC+2232828]
# 	BaseThreadInitThunk [0x76EAFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77257A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77257A4E+238]
